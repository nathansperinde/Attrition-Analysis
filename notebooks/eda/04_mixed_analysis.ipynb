# %%
import importlib

import pandas as pd

import attrition_analysis.associations_test as associations_test
import attrition_analysis.data_selection as data_selection
import attrition_analysis.logistic_models_utils as logistic_models_utils
import attrition_analysis.multicollinearity as multicollinearity

importlib.reload(data_selection)
importlib.reload(associations_test)
importlib.reload(multicollinearity)
importlib.reload(logistic_models_utils)

from attrition_analysis.associations_test import mixed_association_table
from attrition_analysis.data_selection import MIXED_MODEL_VARS
from attrition_analysis.logistic_models_utils import (
    compare_logistic_models,
    run_logistic_models_mixed,
)
from attrition_analysis.multicollinearity import vif_mixed_table

df = pd.read_csv("../../data/clean/Employee-Attrition_Clean.csv")

target = "AttritionFlag"

df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome EducationField  EmployeeCount  EmployeeNumber  Gender  \
# 0                    1  Life Sciences              1               1  Female
# 1                    8  Life Sciences              1               2    Male
# 2                    2          Other              1               4    Male
# 3                    3  Life Sciences              1               5  Female
# 4                    2        Medical              1               7    Male
# ...                ...            ...            ...             ...     ...
# 1465                23        Medical              1            2061    Male
# 1466                 6        Medical              1            2062    Male
# 1467                 4  Life Sciences              1            2064    Male
# 1468                 2        Medical              1            2065    Male
# 1469                 8        Medical              1            2068    Male
#
#       ...  IncomeGroup EducationLevel StockOption  JobLevelGroup  \
# 0     ...       Medium        College  No Options   Junior Level
# 1     ...       Medium  Below College         Low   Junior Level
# 2     ...          Low        College  No Options    Entry Level
# 3     ...          Low         Master  No Options    Entry Level
# 4     ...       Medium  Below College         Low    Entry Level
# ...   ...          ...            ...         ...            ...
# 1465  ...          Low        College         Low   Junior Level
# 1466  ...         High  Below College         Low      Mid Level
# 1467  ...         High       Bachelor         Low   Junior Level
# 1468  ...       Medium       Bachelor  No Options   Junior Level
# 1469  ...       Medium       Bachelor  No Options   Junior Level
#
#       SatisfactionLevel  PerformanceRatingLevel EnvironmentSatisfactionLevel  \
# 0             Very High               Excellent                       Medium
# 1                Medium             Outstanding                         High
# 2                  High               Excellent                    Very High
# 3                  High               Excellent                    Very High
# 4                Medium               Excellent                          Low
# ...                 ...                     ...                          ...
# 1465          Very High               Excellent                         High
# 1466                Low               Excellent                    Very High
# 1467             Medium             Outstanding                       Medium
# 1468             Medium               Excellent                    Very High
# 1469               High               Excellent                       Medium
#
#      JobInvolvementLevel  RelationshipSatisfactionLevel  WorkLifeBalanceLevel
# 0                   High                            Low                   Bad
# 1                 Medium                      Very High                Better
# 2                 Medium                         Medium                Better
# 3                   High                           High                Better
# 4                   High                      Very High                Better
# ...                  ...                            ...                   ...
# 1465           Very High                           High                Better
# 1466              Medium                            Low                Better
# 1467           Very High                         Medium                Better
# 1468              Medium                      Very High                  Good
# 1469           Very High                            Low                  Best
#
# [1470 rows x 43 columns]

# %%
mixed_table = mixed_association_table(df)

mixed_table[mixed_table["Eta_Squared"]>=0.6].sort_values(by="Eta_Squared", ascending=True)
# Out:
#     Categorical_Variable    Quantitative_Variable  Eta_Squared  \
# 248        JobLevelGroup        TotalWorkingYears        0.635
# 154          CareerStage            MonthlyIncome        0.682
# 133          TenureGroup     YearsWithCurrManager        0.690
# 131          TenureGroup       YearsInCurrentRole        0.702
# 64               JobRole            MonthlyIncome        0.816
# 130          TenureGroup           YearsAtCompany        0.818
# 176   RoleStabilityGroup       YearsInCurrentRole        0.877
# 199          IncomeGroup            MonthlyIncome        0.877
# 192  PromotionDelayGroup  YearsSinceLastPromotion        0.878
# 158          CareerStage        TotalWorkingYears        0.898
# 105             AgeGroup                      Age        0.908
# 244        JobLevelGroup            MonthlyIncome        0.925
# 137        DistanceGroup         DistanceFromHome        0.947
#
#      Kruskal_Statistic  p_value Significativo  Força
# 248            814.301      0.0           Sim  Forte
# 154            775.383      0.0           Sim  Forte
# 133           1028.332      0.0           Sim  Forte
# 131           1069.682      0.0           Sim  Forte
# 64            1073.410      0.0           Sim  Forte
# 130           1404.813      0.0           Sim  Forte
# 176           1394.262      0.0           Sim  Forte
# 199           1355.971      0.0           Sim  Forte
# 192           1418.465      0.0           Sim  Forte
# 158           1345.374      0.0           Sim  Forte
# 105           1314.041      0.0           Sim  Forte
# 244           1245.176      0.0           Sim  Forte
# 137           1322.965      0.0           Sim  Forte

# %%
vif_mixed = vif_mixed_table(df)

vif_mixed[vif_mixed["VIF"]>=5]
# Out:
#                               Feature     VIF Multicollinearity
# 0                       MonthlyIncome  47.690             Forte
# 1                    Department_Sales  45.596             Forte
# 2   Department_Research & Development  45.582             Forte
# 3        EducationField_Life Sciences  24.806             Forte
# 4              EducationField_Medical  22.316             Forte
# 5                 DistanceGroup_21-30  19.921             Forte
# 6                    DistanceFromHome  19.827             Forte
# 7                     TenureGroup_10+  18.490             Forte
# 8             CareerStage_Late career  17.932             Forte
# 9                      AgeGroup_46-55  16.829             Forte
# 10            JobRole_Sales Executive  15.133             Forte
# 11                  TotalWorkingYears  14.260             Forte
# 12                     AgeGroup_36-45  13.477             Forte
# 13      JobLevelGroup_Executive Level  13.185             Forte
# 14              RoleStabilityGroup_8+  12.820             Forte
# 15                                Age  12.297             Forte
# 16                   TenureGroup_6-10  12.257             Forte
# 17            YearsSinceLastPromotion  12.159             Forte
# 18         JobLevelGroup_Senior Level  12.079             Forte
# 19           EducationField_Marketing  11.219             Forte
# 20                    IncomeGroup_Low  10.710             Forte
# 21                 YearsInCurrentRole  10.559             Forte
# 22                     YearsAtCompany   9.734          Moderada
# 23       PromotionDelayGroup_5+ years   9.230          Moderada
# 24    EducationField_Technical Degree   9.147          Moderada
# 25             RoleStabilityGroup_4-7   8.704          Moderada
# 26                DistanceGroup_11-20   8.417          Moderada
# 27            CareerStage_Experienced   7.792          Moderada
# 28            JobRole_Human Resources   7.578          Moderada
# 29             StockOption_No Options   7.304          Moderada
# 30              IncomeGroup_Very High   7.180          Moderada
# 31            JobLevelGroup_Mid Level   7.036          Moderada
# 32                    TenureGroup_4-5   7.005          Moderada
# 33                     AgeGroup_56-65   6.946          Moderada
# 34                     AgeGroup_26-35   6.837          Moderada
# 35               EducationField_Other   6.256          Moderada
# 36       JobRole_Sales Representative   6.246          Moderada
# 37             RoleStabilityGroup_2-3   5.956          Moderada
# 38                    TenureGroup_2-3   5.765          Moderada
# 39                 IncomeGroup_Medium   5.625          Moderada
# 40                    JobRole_Manager   5.379          Moderada
# 41         JobLevelGroup_Junior Level   5.212          Moderada
# 42                    StockOption_Low   5.095          Moderada
# 43        WorkLifeBalanceLevel_Better   5.060          Moderada

# %%
mixed_models, mixed_results = run_logistic_models_mixed(
    df=df,
    mixed_models_vars_dict=MIXED_MODEL_VARS,
    target="AttritionFlag"
)

# %%
comparison_df = compare_logistic_models(mixed_models)

comparison_df.round(4)
# Out:
#                                                Model  N_Observations  \
# 0              Modelo 8 — Integrado Multidimensional            1470
# 1          Modelo 2 — Nível Hierárquico e Benefícios            1470
# 2  Modelo 6 — Perfil Pessoal e Condições de Trabalho            1470
# 3               Modelo 1 — Função Profissional Misto            1470
# 4                Modelo 4 — Experiência Profissional            1470
# 5                 Modelo 3 — Rendimento Quantitativo            1470
# 6              Modelo 5 — Antiguidade Organizacional            1470
# 7              Modelo 7 — Reduzido Conservador Misto            1470
#
#    Df_Model  Log_Likelihood   LL_Null  LLR_p_value        AIC        BIC  \
# 0        43       -424.0516 -649.2914          0.0   936.1031  1168.9959
# 1        25       -472.8024 -649.2914          0.0   997.6047  1135.2232
# 2        24       -489.4996 -649.2914          0.0  1028.9993  1161.3247
# 3        26       -488.0639 -649.2914          0.0  1030.1278  1173.0393
# 4        19       -506.7732 -649.2914          0.0  1053.5463  1159.4067
# 5        19       -512.8681 -649.2914          0.0  1065.7362  1171.5966
# 6        20       -518.2259 -649.2914          0.0  1078.4518  1189.6052
# 7        18       -539.1649 -649.2914          0.0  1116.3297  1216.8970
#
#    Pseudo_R2
# 0     0.3469
# 1     0.2718
# 2     0.2461
# 3     0.2483
# 4     0.2195
# 5     0.2101
# 6     0.2019
# 7     0.1696

# %% [markdown]
# # Modelo 1 — Função Profissional Misto
#
# Este modelo foi construído para avaliar a contribuição da função profissional do funcionário, representada por `JobRole`, em conjunto com variáveis quantitativas e categóricas relacionadas às condições de trabalho, satisfação, envolvimento e deslocamento.
#
# **Variáveis numéricas:** `DistanceFromHome`, `DailyRate`, `TrainingTimesLastYear`.
#
# **Variáveis categóricas:** `OverTime`, `JobRole`, `BusinessTravel`, `JobInvolvementLevel`, `EnvironmentSatisfactionLevel`, `SatisfactionLevel`, `WorkLifeBalanceLevel`.

# %%
mixed_results["Modelo 1 — Função Profissional Misto"].round(4)
# Out:
#                                               Coefficient  Odds_Ratio  \
# C(JobRole)[T.Sales Representative]                 2.7230     15.2266
# C(JobRole)[T.Laboratory Technician]                1.7479      5.7424
# C(OverTime)[T.Yes]                                 1.7243      5.6085
# C(JobRole)[T.Human Resources]                      1.6232      5.0691
# C(BusinessTravel)[T.Travel_Frequently]             1.5900      4.9039
# C(JobInvolvementLevel)[T.Low]                      1.3222      3.7517
# C(JobRole)[T.Sales Executive]                      1.2745      3.5769
# C(EnvironmentSatisfactionLevel)[T.Low]             1.0595      2.8849
# C(JobRole)[T.Research Scientist]                   1.0102      2.7461
# C(BusinessTravel)[T.Travel_Rarely]                 0.8647      2.3744
# C(SatisfactionLevel)[T.Low]                        0.5545      1.7411
# C(JobInvolvementLevel)[T.Medium]                   0.3667      1.4430
# DistanceFromHome                                   0.2591      1.2957
# C(SatisfactionLevel)[T.Medium]                     0.1005      1.1057
# C(JobRole)[T.Manufacturing Director]               0.0849      1.0886
# C(EnvironmentSatisfactionLevel)[T.Medium]         -0.0119      0.9882
# C(EnvironmentSatisfactionLevel)[T.Very High]      -0.1279      0.8800
# DailyRate                                         -0.1752      0.8393
# TrainingTimesLastYear                             -0.2071      0.8129
# C(JobRole)[T.Manager]                             -0.2139      0.8074
# C(SatisfactionLevel)[T.Very High]                 -0.6492      0.5225
# C(JobInvolvementLevel)[T.Very High]               -0.6925      0.5003
# C(WorkLifeBalanceLevel)[T.Best]                   -0.8395      0.4319
# C(WorkLifeBalanceLevel)[T.Good]                   -0.9653      0.3809
# C(JobRole)[T.Research Director]                   -1.2427      0.2886
# C(WorkLifeBalanceLevel)[T.Better]                 -1.2822      0.2774
# Intercept                                         -3.7298      0.0240
#
#                                               CI_Lower  CI_Upper  p_value
# C(JobRole)[T.Sales Representative]              6.1873   37.4717   0.0000
# C(JobRole)[T.Laboratory Technician]             2.5720   12.8210   0.0000
# C(OverTime)[T.Yes]                              3.9763    7.9107   0.0000
# C(JobRole)[T.Human Resources]                   1.8105   14.1924   0.0020
# C(BusinessTravel)[T.Travel_Frequently]          2.3599   10.1906   0.0000
# C(JobInvolvementLevel)[T.Low]                   2.0810    6.7637   0.0000
# C(JobRole)[T.Sales Executive]                   1.6138    7.9279   0.0017
# C(EnvironmentSatisfactionLevel)[T.Low]          1.8535    4.4902   0.0000
# C(JobRole)[T.Research Scientist]                1.2239    6.1616   0.0143
# C(BusinessTravel)[T.Travel_Rarely]              1.1991    4.7015   0.0131
# C(SatisfactionLevel)[T.Low]                     1.1305    2.6814   0.0118
# C(JobInvolvementLevel)[T.Medium]                0.9962    2.0902   0.0524
# DistanceFromHome                                1.1099    1.5127   0.0010
# C(SatisfactionLevel)[T.Medium]                  0.6930    1.7641   0.6735
# C(JobRole)[T.Manufacturing Director]            0.4032    2.9389   0.8669
# C(EnvironmentSatisfactionLevel)[T.Medium]       0.6077    1.6069   0.9618
# C(EnvironmentSatisfactionLevel)[T.Very High]    0.5698    1.3589   0.5641
# DailyRate                                       0.7147    0.9857   0.0327
# TrainingTimesLastYear                           0.6827    0.9679   0.0200
# C(JobRole)[T.Manager]                           0.2451    2.6605   0.7252
# C(SatisfactionLevel)[T.Very High]               0.3357    0.8132   0.0040
# C(JobInvolvementLevel)[T.Very High]             0.2571    0.9737   0.0415
# C(WorkLifeBalanceLevel)[T.Best]                 0.2038    0.9154   0.0285
# C(WorkLifeBalanceLevel)[T.Good]                 0.1967    0.7374   0.0042
# C(JobRole)[T.Research Director]                 0.0565    1.4733   0.1352
# C(WorkLifeBalanceLevel)[T.Better]               0.1498    0.5137   0.0000
# Intercept                                       0.0074    0.0782   0.0000

# %% [markdown]
# # Modelo 2 — Nível Hierárquico e Benefícios
#
# Este modelo é centrado no nível hierárquico e nos benefícios do funcionário, utilizando `JobLevelGroup` e `StockOption` como variáveis principais. O objetivo é testar se essas dimensões acrescentam informação à explicação da saída dos funcionários, em conjunto com variáveis de trabalho, satisfação e deslocamento.
#
# **Variáveis numéricas:** `DistanceFromHome`, `DailyRate`, `TrainingTimesLastYear`.
#
# **Variáveis categóricas:** `OverTime`, `JobLevelGroup`, `StockOption`, `BusinessTravel`, `JobInvolvementLevel`, `EnvironmentSatisfactionLevel`, `SatisfactionLevel`, `WorkLifeBalanceLevel`.

# %%
mixed_results["Modelo 2 — Nível Hierárquico e Benefícios"].round(4)
# Out:
#                                               Coefficient  Odds_Ratio  \
# C(BusinessTravel)[T.Travel_Frequently]             1.6922      5.4317
# C(OverTime)[T.Yes]                                 1.6566      5.2412
# C(JobInvolvementLevel)[T.Low]                      1.4813      4.3988
# C(EnvironmentSatisfactionLevel)[T.Low]             0.9311      2.5372
# C(BusinessTravel)[T.Travel_Rarely]                 0.9125      2.4906
# C(StockOption)[T.No Options]                       0.5881      1.8005
# C(SatisfactionLevel)[T.Low]                        0.4919      1.6354
# C(JobInvolvementLevel)[T.Medium]                   0.3301      1.3911
# DistanceFromHome                                   0.3200      1.3772
# C(EnvironmentSatisfactionLevel)[T.Medium]          0.0913      1.0956
# C(SatisfactionLevel)[T.Medium]                     0.0653      1.0675
# C(EnvironmentSatisfactionLevel)[T.Very High]      -0.1585      0.8534
# DailyRate                                         -0.1664      0.8467
# TrainingTimesLastYear                             -0.2033      0.8160
# C(SatisfactionLevel)[T.Very High]                 -0.6244      0.5356
# C(StockOption)[T.Medium]                          -0.6745      0.5094
# C(StockOption)[T.Low]                             -0.6865      0.5033
# C(JobInvolvementLevel)[T.Very High]               -0.7258      0.4840
# C(WorkLifeBalanceLevel)[T.Best]                   -0.7262      0.4837
# C(WorkLifeBalanceLevel)[T.Good]                   -0.8496      0.4276
# C(JobLevelGroup)[T.Mid Level]                     -0.9077      0.4034
# C(WorkLifeBalanceLevel)[T.Better]                 -1.1857      0.3055
# C(JobLevelGroup)[T.Junior Level]                  -1.3733      0.2533
# C(JobLevelGroup)[T.Executive Level]               -1.6042      0.2011
# Intercept                                         -1.9692      0.1396
# C(JobLevelGroup)[T.Senior Level]                  -2.3520      0.0952
#
#                                               CI_Lower  CI_Upper  p_value
# C(BusinessTravel)[T.Travel_Frequently]          2.5097   11.7557   0.0000
# C(OverTime)[T.Yes]                              3.7144    7.3957   0.0000
# C(JobInvolvementLevel)[T.Low]                   2.3878    8.1034   0.0000
# C(EnvironmentSatisfactionLevel)[T.Low]          1.6096    3.9995   0.0001
# C(BusinessTravel)[T.Travel_Rarely]              1.2073    5.1377   0.0135
# C(StockOption)[T.No Options]                    0.8964    3.6164   0.0984
# C(SatisfactionLevel)[T.Low]                     1.0538    2.5378   0.0283
# C(JobInvolvementLevel)[T.Medium]                0.9532    2.0302   0.0870
# DistanceFromHome                                1.1711    1.6195   0.0001
# C(EnvironmentSatisfactionLevel)[T.Medium]       0.6707    1.7896   0.7154
# C(SatisfactionLevel)[T.Medium]                  0.6623    1.7204   0.7886
# C(EnvironmentSatisfactionLevel)[T.Very High]    0.5498    1.3247   0.4797
# DailyRate                                       0.7187    0.9976   0.0467
# TrainingTimesLastYear                           0.6846    0.9728   0.0233
# C(SatisfactionLevel)[T.Very High]               0.3425    0.8374   0.0062
# C(StockOption)[T.Medium]                        0.2035    1.2752   0.1497
# C(StockOption)[T.Low]                           0.2425    1.0445   0.0653
# C(JobInvolvementLevel)[T.Very High]             0.2454    0.9545   0.0362
# C(WorkLifeBalanceLevel)[T.Best]                 0.2255    1.0379   0.0622
# C(WorkLifeBalanceLevel)[T.Good]                 0.2194    0.8334   0.0126
# C(JobLevelGroup)[T.Mid Level]                   0.2474    0.6579   0.0003
# C(WorkLifeBalanceLevel)[T.Better]               0.1641    0.5690   0.0002
# C(JobLevelGroup)[T.Junior Level]                0.1704    0.3764   0.0000
# C(JobLevelGroup)[T.Executive Level]             0.0704    0.5743   0.0027
# Intercept                                       0.0420    0.4642   0.0013
# C(JobLevelGroup)[T.Senior Level]                0.0345    0.2622   0.0000

# %% [markdown]
# # Modelo 3 — Rendimento Quantitativo
#
# Este modelo utiliza `MonthlyIncome` como variável quantitativa principal, permitindo avaliar se o rendimento mensal acrescenta capacidade explicativa ao modelo. Para evitar redundância, não inclui a versão categorizada da remuneração, `IncomeGroup`.
#
# **Variáveis numéricas:** `MonthlyIncome`, `DistanceFromHome`, `DailyRate`, `TrainingTimesLastYear`.
#
# **Variáveis categóricas:** `OverTime`, `BusinessTravel`, `JobInvolvementLevel`, `EnvironmentSatisfactionLevel`, `SatisfactionLevel`, `WorkLifeBalanceLevel`.

# %%
mixed_results["Modelo 3 — Rendimento Quantitativo"].round(4)
# Out:
#                                               Coefficient  Odds_Ratio  \
# C(BusinessTravel)[T.Travel_Frequently]             1.6654      5.2876
# C(OverTime)[T.Yes]                                 1.6154      5.0297
# C(JobInvolvementLevel)[T.Low]                      1.3996      4.0535
# C(EnvironmentSatisfactionLevel)[T.Low]             0.9915      2.6952
# C(BusinessTravel)[T.Travel_Rarely]                 0.9415      2.5637
# C(SatisfactionLevel)[T.Low]                        0.5275      1.6947
# C(JobInvolvementLevel)[T.Medium]                   0.3731      1.4522
# DistanceFromHome                                   0.2373      1.2678
# C(SatisfactionLevel)[T.Medium]                     0.1029      1.1083
# C(EnvironmentSatisfactionLevel)[T.Medium]          0.0363      1.0370
# C(EnvironmentSatisfactionLevel)[T.Very High]      -0.1501      0.8606
# DailyRate                                         -0.1633      0.8493
# TrainingTimesLastYear                             -0.1792      0.8359
# C(SatisfactionLevel)[T.Very High]                 -0.6322      0.5314
# C(WorkLifeBalanceLevel)[T.Best]                   -0.6526      0.5207
# MonthlyIncome                                     -0.7118      0.4908
# C(JobInvolvementLevel)[T.Very High]               -0.7468      0.4739
# C(WorkLifeBalanceLevel)[T.Good]                   -0.8586      0.4237
# C(WorkLifeBalanceLevel)[T.Better]                 -1.1100      0.3296
# Intercept                                         -2.8628      0.0571
#
#                                               CI_Lower  CI_Upper  p_value
# C(BusinessTravel)[T.Travel_Frequently]          2.5509   10.9603   0.0000
# C(OverTime)[T.Yes]                              3.6246    6.9794   0.0000
# C(JobInvolvementLevel)[T.Low]                   2.2791    7.2095   0.0000
# C(EnvironmentSatisfactionLevel)[T.Low]          1.7508    4.1490   0.0000
# C(BusinessTravel)[T.Travel_Rarely]              1.2933    5.0819   0.0070
# C(SatisfactionLevel)[T.Low]                     1.1146    2.5766   0.0136
# C(JobInvolvementLevel)[T.Medium]                1.0128    2.0823   0.0425
# DistanceFromHome                                1.0909    1.4734   0.0020
# C(SatisfactionLevel)[T.Medium]                  0.7031    1.7471   0.6578
# C(EnvironmentSatisfactionLevel)[T.Medium]       0.6479    1.6599   0.8797
# C(EnvironmentSatisfactionLevel)[T.Very High]    0.5649    1.3113   0.4849
# DailyRate                                       0.7260    0.9936   0.0413
# TrainingTimesLastYear                           0.7071    0.9882   0.0358
# C(SatisfactionLevel)[T.Very High]               0.3455    0.8175   0.0040
# C(WorkLifeBalanceLevel)[T.Best]                 0.2536    1.0691   0.0754
# MonthlyIncome                                   0.3935    0.6122   0.0000
# C(JobInvolvementLevel)[T.Very High]             0.2459    0.9133   0.0257
# C(WorkLifeBalanceLevel)[T.Good]                 0.2248    0.7988   0.0079
# C(WorkLifeBalanceLevel)[T.Better]               0.1829    0.5937   0.0002
# Intercept                                       0.0222    0.1470   0.0000

# %% [markdown]
# # Modelo 4 — Experiência Profissional
#
# Este modelo é focado na experiência profissional acumulada, representada por `TotalWorkingYears`. A proposta é testar se o tempo total de carreira contribui para explicar o attrition quando analisado juntamente com variáveis de trabalho, satisfação e deslocamento.
#
# **Variáveis numéricas:** `TotalWorkingYears`, `DistanceFromHome`, `DailyRate`, `TrainingTimesLastYear`.
#
# **Variáveis categóricas:** `OverTime`, `BusinessTravel`, `JobInvolvementLevel`, `EnvironmentSatisfactionLevel`, `SatisfactionLevel`, `WorkLifeBalanceLevel`.

# %%
mixed_results["Modelo 4 — Experiência Profissional"].round(4)
# Out:
#                                               Coefficient  Odds_Ratio  \
# C(BusinessTravel)[T.Travel_Frequently]             1.7658      5.8464
# C(OverTime)[T.Yes]                                 1.6487      5.2003
# C(JobInvolvementLevel)[T.Low]                      1.4075      4.0857
# C(EnvironmentSatisfactionLevel)[T.Low]             1.0300      2.8012
# C(BusinessTravel)[T.Travel_Rarely]                 0.9847      2.6771
# C(SatisfactionLevel)[T.Low]                        0.5679      1.7646
# C(JobInvolvementLevel)[T.Medium]                   0.3666      1.4428
# DistanceFromHome                                   0.2486      1.2822
# C(SatisfactionLevel)[T.Medium]                     0.0741      1.0769
# C(EnvironmentSatisfactionLevel)[T.Medium]          0.0637      1.0658
# C(EnvironmentSatisfactionLevel)[T.Very High]      -0.1303      0.8779
# DailyRate                                         -0.1430      0.8668
# TrainingTimesLastYear                             -0.1805      0.8349
# C(SatisfactionLevel)[T.Very High]                 -0.6695      0.5120
# C(JobInvolvementLevel)[T.Very High]               -0.7157      0.4888
# TotalWorkingYears                                 -0.7483      0.4732
# C(WorkLifeBalanceLevel)[T.Best]                   -0.7698      0.4631
# C(WorkLifeBalanceLevel)[T.Good]                   -0.9139      0.4010
# C(WorkLifeBalanceLevel)[T.Better]                 -1.1887      0.3046
# Intercept                                         -2.8856      0.0558
#
#                                               CI_Lower  CI_Upper  p_value
# C(BusinessTravel)[T.Travel_Frequently]          2.8043   12.1884   0.0000
# C(OverTime)[T.Yes]                              3.7365    7.2377   0.0000
# C(JobInvolvementLevel)[T.Low]                   2.2877    7.2969   0.0000
# C(EnvironmentSatisfactionLevel)[T.Low]          1.8135    4.3269   0.0000
# C(BusinessTravel)[T.Travel_Rarely]              1.3458    5.3254   0.0050
# C(SatisfactionLevel)[T.Low]                     1.1573    2.6905   0.0083
# C(JobInvolvementLevel)[T.Medium]                1.0041    2.0731   0.0475
# DistanceFromHome                                1.1013    1.4928   0.0014
# C(SatisfactionLevel)[T.Medium]                  0.6813    1.7024   0.7510
# C(EnvironmentSatisfactionLevel)[T.Medium]       0.6636    1.7115   0.7922
# C(EnvironmentSatisfactionLevel)[T.Very High]    0.5747    1.3410   0.5468
# DailyRate                                       0.7400    1.0152   0.0763
# TrainingTimesLastYear                           0.7070    0.9859   0.0334
# C(SatisfactionLevel)[T.Very High]               0.3315    0.7908   0.0025
# C(JobInvolvementLevel)[T.Very High]             0.2534    0.9429   0.0327
# TotalWorkingYears                               0.3854    0.5810   0.0000
# C(WorkLifeBalanceLevel)[T.Best]                 0.2264    0.9471   0.0350
# C(WorkLifeBalanceLevel)[T.Good]                 0.2134    0.7535   0.0045
# C(WorkLifeBalanceLevel)[T.Better]               0.1699    0.5460   0.0001
# Intercept                                       0.0217    0.1436   0.0000

# %% [markdown]
# # Modelo 5 — Antiguidade Organizacional
#
# Este modelo avalia a permanência do funcionário na empresa, utilizando `YearsAtCompany` e `YearsSinceLastPromotion` como variáveis principais. O objetivo é testar se a antiguidade organizacional e o tempo desde a última promoção acrescentam informação à explicação da saída dos funcionários.
#
# **Variáveis numéricas:** `YearsAtCompany`, `YearsSinceLastPromotion`, `DistanceFromHome`, `DailyRate`, `TrainingTimesLastYear`.
#
# **Variáveis categóricas:** `OverTime`, `BusinessTravel`, `JobInvolvementLevel`, `EnvironmentSatisfactionLevel`, `SatisfactionLevel`, `WorkLifeBalanceLevel`.

# %%
mixed_results["Modelo 5 — Antiguidade Organizacional"].round(4)
# Out:
#                                               Coefficient  Odds_Ratio  \
# C(BusinessTravel)[T.Travel_Frequently]             1.6916      5.4282
# C(OverTime)[T.Yes]                                 1.5743      4.8276
# C(JobInvolvementLevel)[T.Low]                      1.4023      4.0645
# C(EnvironmentSatisfactionLevel)[T.Low]             0.9394      2.5584
# C(BusinessTravel)[T.Travel_Rarely]                 0.9083      2.4802
# C(SatisfactionLevel)[T.Low]                        0.4882      1.6293
# C(JobInvolvementLevel)[T.Medium]                   0.4165      1.5167
# YearsSinceLastPromotion                            0.3646      1.4400
# DistanceFromHome                                   0.2311      1.2600
# C(SatisfactionLevel)[T.Medium]                     0.0924      1.0968
# C(EnvironmentSatisfactionLevel)[T.Medium]          0.0459      1.0470
# C(EnvironmentSatisfactionLevel)[T.Very High]      -0.1466      0.8637
# DailyRate                                         -0.1530      0.8582
# TrainingTimesLastYear                             -0.1599      0.8522
# C(SatisfactionLevel)[T.Very High]                 -0.6100      0.5433
# C(JobInvolvementLevel)[T.Very High]               -0.6336      0.5307
# C(WorkLifeBalanceLevel)[T.Best]                   -0.7321      0.4809
# YearsAtCompany                                    -0.7778      0.4594
# C(WorkLifeBalanceLevel)[T.Good]                   -0.9590      0.3833
# C(WorkLifeBalanceLevel)[T.Better]                 -1.1773      0.3081
# Intercept                                         -2.7336      0.0650
#
#                                               CI_Lower  CI_Upper  p_value
# C(BusinessTravel)[T.Travel_Frequently]          2.6192   11.2495   0.0000
# C(OverTime)[T.Yes]                              3.4879    6.6818   0.0000
# C(JobInvolvementLevel)[T.Low]                   2.2943    7.2005   0.0000
# C(EnvironmentSatisfactionLevel)[T.Low]          1.6637    3.9342   0.0000
# C(BusinessTravel)[T.Travel_Rarely]              1.2527    4.9104   0.0091
# C(SatisfactionLevel)[T.Low]                     1.0723    2.4758   0.0222
# C(JobInvolvementLevel)[T.Medium]                1.0596    2.1711   0.0228
# YearsSinceLastPromotion                         1.1441    1.8123   0.0019
# DistanceFromHome                                1.0853    1.4629   0.0024
# C(SatisfactionLevel)[T.Medium]                  0.6978    1.7240   0.6888
# C(EnvironmentSatisfactionLevel)[T.Medium]       0.6541    1.6759   0.8482
# C(EnvironmentSatisfactionLevel)[T.Very High]    0.5674    1.3146   0.4941
# DailyRate                                       0.7339    1.0035   0.0553
# TrainingTimesLastYear                           0.7229    1.0047   0.0569
# C(SatisfactionLevel)[T.Very High]               0.3544    0.8331   0.0051
# C(JobInvolvementLevel)[T.Very High]             0.2765    1.0184   0.0568
# C(WorkLifeBalanceLevel)[T.Best]                 0.2373    0.9743   0.0421
# YearsAtCompany                                  0.3497    0.6034   0.0000
# C(WorkLifeBalanceLevel)[T.Good]                 0.2045    0.7184   0.0028
# C(WorkLifeBalanceLevel)[T.Better]               0.1724    0.5506   0.0001
# Intercept                                       0.0255    0.1658   0.0000

# %% [markdown]
# # Modelo 6 — Perfil Pessoal e Condições de Trabalho
#
# Este modelo incorpora características pessoais e sociodemográficas, representadas por `AgeGroup` e `MaritalStatus`, juntamente com variáveis relacionadas às condições de trabalho, satisfação, envolvimento e deslocamento.
#
# **Variáveis numéricas:** `DistanceFromHome`, `DailyRate`, `TrainingTimesLastYear`.
#
# **Variáveis categóricas:** `OverTime`, `AgeGroup`, `MaritalStatus`, `BusinessTravel`, `JobInvolvementLevel`, `EnvironmentSatisfactionLevel`, `SatisfactionLevel`, `WorkLifeBalanceLevel`.

# %%
mixed_results["Modelo 6 — Perfil Pessoal e Condições de Trabalho"].round(4)
# Out:
#                                               Coefficient  Odds_Ratio  \
# C(OverTime)[T.Yes]                                 1.6871      5.4035
# C(BusinessTravel)[T.Travel_Frequently]             1.6593      5.2557
# C(JobInvolvementLevel)[T.Low]                      1.4549      4.2841
# C(MaritalStatus)[T.Single]                         1.1596      3.1885
# C(EnvironmentSatisfactionLevel)[T.Low]             0.9657      2.6267
# C(BusinessTravel)[T.Travel_Rarely]                 0.8780      2.4060
# C(SatisfactionLevel)[T.Low]                        0.5641      1.7579
# C(JobInvolvementLevel)[T.Medium]                   0.3366      1.4002
# DistanceFromHome                                   0.2617      1.2991
# C(MaritalStatus)[T.Married]                        0.2223      1.2489
# C(EnvironmentSatisfactionLevel)[T.Medium]          0.1527      1.1649
# C(SatisfactionLevel)[T.Medium]                     0.1160      1.1230
# DailyRate                                         -0.1139      0.8924
# C(EnvironmentSatisfactionLevel)[T.Very High]      -0.1876      0.8290
# TrainingTimesLastYear                             -0.2030      0.8163
# C(SatisfactionLevel)[T.Very High]                 -0.6891      0.5020
# C(JobInvolvementLevel)[T.Very High]               -0.7258      0.4839
# C(WorkLifeBalanceLevel)[T.Best]                   -0.8983      0.4073
# C(WorkLifeBalanceLevel)[T.Good]                   -0.9816      0.3747
# C(AgeGroup)[T.26-35]                              -1.0052      0.3660
# C(AgeGroup)[T.56-65]                              -1.1931      0.3033
# C(WorkLifeBalanceLevel)[T.Better]                 -1.3124      0.2692
# C(AgeGroup)[T.46-55]                              -1.6366      0.1946
# Intercept                                         -1.8757      0.1532
# C(AgeGroup)[T.36-45]                              -1.9062      0.1486
#
#                                               CI_Lower  CI_Upper  p_value
# C(OverTime)[T.Yes]                              3.8464    7.5910   0.0000
# C(BusinessTravel)[T.Travel_Frequently]          2.4872   11.1059   0.0000
# C(JobInvolvementLevel)[T.Low]                   2.3616    7.7717   0.0000
# C(MaritalStatus)[T.Single]                      1.9862    5.1186   0.0000
# C(EnvironmentSatisfactionLevel)[T.Low]          1.6761    4.1164   0.0000
# C(BusinessTravel)[T.Travel_Rarely]              1.1964    4.8386   0.0138
# C(SatisfactionLevel)[T.Low]                     1.1422    2.7054   0.0103
# C(JobInvolvementLevel)[T.Medium]                0.9665    2.0284   0.0751
# DistanceFromHome                                1.1142    1.5148   0.0008
# C(MaritalStatus)[T.Married]                     0.7788    2.0028   0.3563
# C(EnvironmentSatisfactionLevel)[T.Medium]       0.7184    1.8889   0.5359
# C(SatisfactionLevel)[T.Medium]                  0.7017    1.7974   0.6287
# DailyRate                                       0.7585    1.0498   0.1695
# C(EnvironmentSatisfactionLevel)[T.Very High]    0.5373    1.2791   0.3967
# TrainingTimesLastYear                           0.6879    0.9686   0.0201
# C(SatisfactionLevel)[T.Very High]               0.3218    0.7831   0.0024
# C(JobInvolvementLevel)[T.Very High]             0.2473    0.9471   0.0341
# C(WorkLifeBalanceLevel)[T.Best]                 0.1957    0.8477   0.0163
# C(WorkLifeBalanceLevel)[T.Good]                 0.1980    0.7092   0.0026
# C(AgeGroup)[T.26-35]                            0.2222    0.6028   0.0001
# C(AgeGroup)[T.56-65]                            0.1189    0.7737   0.0125
# C(WorkLifeBalanceLevel)[T.Better]               0.1487    0.4872   0.0000
# C(AgeGroup)[T.46-55]                            0.1029    0.3681   0.0000
# Intercept                                       0.0501    0.4684   0.0010
# C(AgeGroup)[T.36-45]                            0.0845    0.2613   0.0000

# %% [markdown]
# # Modelo 7 — Reduzido Conservador Misto
#
# Este modelo reúne uma seleção mais simples e conservadora de variáveis numéricas e categóricas, evitando variáveis temáticas mais específicas ou potencialmente redundantes. Serve como referência para comparação com os demais modelos mistos.
#
# **Variáveis numéricas:** `DistanceFromHome`, `DailyRate`, `TrainingTimesLastYear`.
#
# **Variáveis categóricas:** `OverTime`, `BusinessTravel`, `JobInvolvementLevel`, `EnvironmentSatisfactionLevel`, `SatisfactionLevel`, `WorkLifeBalanceLevel`.

# %%
mixed_results["Modelo 7 — Reduzido Conservador Misto"].round(4)
# Out:
#                                               Coefficient  Odds_Ratio  \
# C(BusinessTravel)[T.Travel_Frequently]             1.6240      5.0732
# C(OverTime)[T.Yes]                                 1.5478      4.7013
# C(JobInvolvementLevel)[T.Low]                      1.3751      3.9555
# C(EnvironmentSatisfactionLevel)[T.Low]             0.9550      2.5987
# C(BusinessTravel)[T.Travel_Rarely]                 0.9078      2.4788
# C(SatisfactionLevel)[T.Low]                        0.5025      1.6528
# C(JobInvolvementLevel)[T.Medium]                   0.4041      1.4980
# DistanceFromHome                                   0.2122      1.2364
# C(EnvironmentSatisfactionLevel)[T.Medium]          0.0961      1.1008
# C(SatisfactionLevel)[T.Medium]                     0.0903      1.0945
# C(EnvironmentSatisfactionLevel)[T.Very High]      -0.1065      0.8990
# DailyRate                                         -0.1571      0.8546
# TrainingTimesLastYear                             -0.1582      0.8537
# C(SatisfactionLevel)[T.Very High]                 -0.6126      0.5419
# C(JobInvolvementLevel)[T.Very High]               -0.6808      0.5062
# C(WorkLifeBalanceLevel)[T.Best]                   -0.7234      0.4851
# C(WorkLifeBalanceLevel)[T.Good]                   -0.9128      0.4014
# C(WorkLifeBalanceLevel)[T.Better]                 -1.1632      0.3125
# Intercept                                         -2.6483      0.0708
#
#                                               CI_Lower  CI_Upper  p_value
# C(BusinessTravel)[T.Travel_Frequently]          2.4943   10.3188   0.0000
# C(OverTime)[T.Yes]                              3.4224    6.4582   0.0000
# C(JobInvolvementLevel)[T.Low]                   2.2616    6.9183   0.0000
# C(EnvironmentSatisfactionLevel)[T.Low]          1.7060    3.9586   0.0000
# C(BusinessTravel)[T.Travel_Rarely]              1.2724    4.8288   0.0076
# C(SatisfactionLevel)[T.Low]                     1.0984    2.4872   0.0160
# C(JobInvolvementLevel)[T.Medium]                1.0556    2.1257   0.0236
# DistanceFromHome                                1.0695    1.4294   0.0041
# C(EnvironmentSatisfactionLevel)[T.Medium]       0.6945    1.7449   0.6827
# C(SatisfactionLevel)[T.Medium]                  0.7033    1.7034   0.6889
# C(EnvironmentSatisfactionLevel)[T.Very High]    0.5948    1.3587   0.6133
# DailyRate                                       0.7331    0.9963   0.0447
# TrainingTimesLastYear                           0.7244    1.0060   0.0590
# C(SatisfactionLevel)[T.Very High]               0.3559    0.8252   0.0043
# C(JobInvolvementLevel)[T.Very High]             0.2646    0.9686   0.0398
# C(WorkLifeBalanceLevel)[T.Best]                 0.2433    0.9671   0.0399
# C(WorkLifeBalanceLevel)[T.Good]                 0.2178    0.7398   0.0034
# C(WorkLifeBalanceLevel)[T.Better]               0.1775    0.5502   0.0001
# Intercept                                       0.0281    0.1780   0.0000

# %% [markdown]
# # Modelo 8 — Modelo Integrado Multidimensional
#
# Este modelo reúne as principais variáveis categóricas e quantitativas selecionadas a partir das análises anteriores. A sua construção combina diferentes dimensões associadas ao attrition, incluindo remuneração, experiência profissional, antiguidade organizacional, função, nível hierárquico, benefícios, perfil pessoal, condições de trabalho, satisfação e deslocamento.
#
# Embora seja o modelo mais abrangente entre os modelos testados, foram evitadas variáveis que representam diretamente versões duplicadas da mesma informação, como `IncomeGroup` e `MonthlyIncome`, `DistanceGroup` e `DistanceFromHome`, `AgeGroup` e `Age`, ou `TenureGroup` e `YearsAtCompany`.
#
# **Variáveis numéricas:** `MonthlyIncome`, `TotalWorkingYears`, `YearsAtCompany`, `YearsSinceLastPromotion`, `DistanceFromHome`, `DailyRate`, `TrainingTimesLastYear`.
#
# **Variáveis categóricas:** `OverTime`, `JobRole`, `JobLevelGroup`, `StockOption`, `AgeGroup`, `MaritalStatus`, `BusinessTravel`, `JobInvolvementLevel`, `EnvironmentSatisfactionLevel`, `SatisfactionLevel`, `WorkLifeBalanceLevel`.

# %%
mixed_results["Modelo 8 — Integrado Multidimensional"].round(4)
# Out:
#                                               Coefficient  Odds_Ratio  \
# C(JobLevelGroup)[T.Executive Level]                2.5122     12.3314
# C(OverTime)[T.Yes]                                 1.9582      7.0865
# C(BusinessTravel)[T.Travel_Frequently]             1.8828      6.5718
# C(JobInvolvementLevel)[T.Low]                      1.5072      4.5141
# C(JobRole)[T.Sales Executive]                      1.3287      3.7762
# C(EnvironmentSatisfactionLevel)[T.Low]             1.1630      3.1996
# C(JobRole)[T.Sales Representative]                 1.1254      3.0814
# C(BusinessTravel)[T.Travel_Rarely]                 0.9744      2.6495
# C(JobRole)[T.Human Resources]                      0.6932      2.0000
# C(JobRole)[T.Laboratory Technician]                0.6224      1.8634
# C(SatisfactionLevel)[T.Low]                        0.5792      1.7846
# C(MaritalStatus)[T.Single]                         0.4454      1.5611
# YearsSinceLastPromotion                            0.3821      1.4654
# DistanceFromHome                                   0.3554      1.4268
# C(StockOption)[T.No Options]                       0.3190      1.3757
# C(JobInvolvementLevel)[T.Medium]                   0.2984      1.3477
# C(MaritalStatus)[T.Married]                        0.1754      1.1917
# C(JobRole)[T.Manufacturing Director]               0.1581      1.1713
# C(EnvironmentSatisfactionLevel)[T.Medium]          0.1092      1.1154
# C(SatisfactionLevel)[T.Medium]                     0.0473      1.0484
# C(JobLevelGroup)[T.Mid Level]                     -0.0115      0.9886
# C(AgeGroup)[T.56-65]                              -0.0811      0.9221
# DailyRate                                         -0.1736      0.8407
# C(EnvironmentSatisfactionLevel)[T.Very High]      -0.1832      0.8326
# C(JobLevelGroup)[T.Senior Level]                  -0.2324      0.7926
# TrainingTimesLastYear                             -0.2418      0.7852
# C(AgeGroup)[T.46-55]                              -0.2601      0.7710
# C(JobRole)[T.Research Scientist]                  -0.2969      0.7431
# TotalWorkingYears                                 -0.3021      0.7393
# MonthlyIncome                                     -0.3662      0.6934
# YearsAtCompany                                    -0.3698      0.6909
# C(AgeGroup)[T.26-35]                              -0.3824      0.6822
# C(JobInvolvementLevel)[T.Very High]               -0.6341      0.5304
# C(SatisfactionLevel)[T.Very High]                 -0.6522      0.5209
# C(StockOption)[T.Low]                             -0.7197      0.4869
# C(StockOption)[T.Medium]                          -0.7205      0.4865
# C(AgeGroup)[T.36-45]                              -0.8590      0.4236
# C(JobRole)[T.Manager]                             -0.9483      0.3874
# C(WorkLifeBalanceLevel)[T.Best]                   -0.9721      0.3783
# C(WorkLifeBalanceLevel)[T.Good]                   -1.0688      0.3434
# C(JobLevelGroup)[T.Junior Level]                  -1.3456      0.2604
# C(WorkLifeBalanceLevel)[T.Better]                 -1.4363      0.2378
# C(JobRole)[T.Research Director]                   -2.3375      0.0966
# Intercept                                         -2.6581      0.0701
#
#                                               CI_Lower  CI_Upper  p_value
# C(JobLevelGroup)[T.Executive Level]             0.6164  246.6898   0.1003
# C(OverTime)[T.Yes]                              4.8309   10.3953   0.0000
# C(BusinessTravel)[T.Travel_Frequently]          2.9262   14.7592   0.0000
# C(JobInvolvementLevel)[T.Low]                   2.3255    8.7625   0.0000
# C(JobRole)[T.Sales Executive]                   1.6018    8.9023   0.0024
# C(EnvironmentSatisfactionLevel)[T.Low]          1.9579    5.2289   0.0000
# C(JobRole)[T.Sales Representative]              0.8740   10.8630   0.0800
# C(BusinessTravel)[T.Travel_Rarely]              1.2547    5.5950   0.0106
# C(JobRole)[T.Human Resources]                   0.5659    7.0689   0.2819
# C(JobRole)[T.Laboratory Technician]             0.5937    5.8484   0.2862
# C(SatisfactionLevel)[T.Low]                     1.1141    2.8587   0.0160
# C(MaritalStatus)[T.Single]                      0.7303    3.3370   0.2506
# YearsSinceLastPromotion                         1.1255    1.9078   0.0045
# DistanceFromHome                                1.1982    1.6990   0.0001
# C(StockOption)[T.No Options]                    0.5722    3.3075   0.4760
# C(JobInvolvementLevel)[T.Medium]                0.9004    2.0174   0.1471
# C(MaritalStatus)[T.Married]                     0.6936    2.0475   0.5255
# C(JobRole)[T.Manufacturing Director]            0.4105    3.3423   0.7675
# C(EnvironmentSatisfactionLevel)[T.Medium]       0.6607    1.8830   0.6828
# C(SatisfactionLevel)[T.Medium]                  0.6277    1.7510   0.8567
# C(JobLevelGroup)[T.Mid Level]                   0.2583    3.7832   0.9866
# C(AgeGroup)[T.56-65]                            0.2941    2.8911   0.8893
# DailyRate                                       0.7057    1.0014   0.0519
# C(EnvironmentSatisfactionLevel)[T.Very High]    0.5212    1.3300   0.4433
# C(JobLevelGroup)[T.Senior Level]                0.0816    7.7029   0.8412
# TrainingTimesLastYear                           0.6525    0.9450   0.0105
# C(AgeGroup)[T.46-55]                            0.3283    1.8106   0.5504
# C(JobRole)[T.Research Scientist]                0.2304    2.3963   0.6192
# TotalWorkingYears                               0.4857    1.1253   0.1587
# MonthlyIncome                                   0.3041    1.5809   0.3839
# YearsAtCompany                                  0.4906    0.9728   0.0342
# C(AgeGroup)[T.26-35]                            0.3907    1.1912   0.1787
# C(JobInvolvementLevel)[T.Very High]             0.2596    1.0837   0.0819
# C(SatisfactionLevel)[T.Very High]               0.3246    0.8357   0.0069
# C(StockOption)[T.Low]                           0.2249    1.0540   0.0678
# C(StockOption)[T.Medium]                        0.1841    1.2855   0.1461
# C(AgeGroup)[T.36-45]                            0.2164    0.8290   0.0122
# C(JobRole)[T.Manager]                           0.0542    2.7712   0.3449
# C(WorkLifeBalanceLevel)[T.Best]                 0.1674    0.8549   0.0194
# C(WorkLifeBalanceLevel)[T.Good]                 0.1683    0.7006   0.0033
# C(JobLevelGroup)[T.Junior Level]                0.1076    0.6302   0.0028
# C(WorkLifeBalanceLevel)[T.Better]               0.1224    0.4620   0.0000
# C(JobRole)[T.Research Director]                 0.0106    0.8816   0.0383
# Intercept                                       0.0108    0.4529   0.0052
